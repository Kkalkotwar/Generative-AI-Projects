# %%
! pip install langchain_groq
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.8/108.8 kB 3.1 MB/s eta 0:00:00
# ...

# %%
from langchain_groq import ChatGroq

# First go to GroqCloud----> Do Login ----> Go to API and create a new API key. Dont share with anyone
# Link to GroqCloud - https://console.groq.com/login
"""
It facilitates real-time streaming, integration of various tools,
and connection to external sources to enhance the intelligence of applications.
"""
# It is a cloud platform for using Open Source LLM Model [In Our case LLAMA-3.1]
llm = ChatGroq(
    temperature=0,
    groq_api_key='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', # It a Demo API Key (You need to replace with your own API Key)
    model_name="llama-3.1-70b-versatile"
)

response = llm.invoke("Who was the the king of Maharashtra in 1800 AD") # -----> You can change the question,prompt according to your will
print(response.content)
# Out:
# In 1800 AD, the king of Maharashtra was not a single ruler, as the region was divided into several smaller kingdoms and territories. However, some of the prominent rulers of Maharashtra during that time were:
#
# 1. Peshwa Bajirao II (1796-1818): He was the Peshwa (Prime Minister) of the Maratha Empire, which was a powerful kingdom that ruled over much of Maharashtra. Although the Peshwa was not technically a king, he held significant power and influence over the region.
# 2. Daulat Rao Sindhia (1794-1827): He was the ruler of the Gwalior State, which was a Maratha kingdom that controlled parts of Maharashtra, including the city of Nagpur.
# 3. Raghoji II Bhonsle (1788-1816): He was the ruler of the Nagpur Kingdom, which was a Maratha kingdom that controlled parts of eastern Maharashtra.
#
# ...
